# %%
import os

os.makedirs(os.path.join('.', 'data'), exist_ok=True)
data_file = os.path.join('.', 'data', 'house_tiny.csv')
with open(data_file, 'w') as f:
    f.write('NumRooms, Alley, Price\n')
    f.write('NA, Pave, 125600\n')
    f.write('2,NA,106000\n')
    f.write('4,NA,178100\n')
    f.write('NA,NA,150000')

# %%
import pandas as pd

data = pd.read_csv(data_file)
print(data)
# Out:
#    NumRooms  Alley   Price
# 0       NaN   Pave  125600
# 1       2.0    NaN  106000
# 2       4.0    NaN  178100
# 3       NaN    NaN  150000

# %%
data
# Out:
#    NumRooms  Alley   Price
# 0       NaN   Pave  125600
# 1       2.0    NaN  106000
# 2       4.0    NaN  178100
# 3       NaN    NaN  150000

# %%
inputs, outputs = data.iloc[:, 0:1], data.iloc[:, 2]
inputs = inputs.fillna(inputs.mean())
print(inputs)
# Out:
#    NumRooms
# 0       3.0
# 1       2.0
# 2       4.0
# 3       3.0

# %%
import torch
a = torch.arange(12)
b = a.reshape(3, 4)
b[0] = 2
a
# Out:
# tensor([ 2,  2,  2,  2,  4,  5,  6,  7,  8,  9, 10, 11])
